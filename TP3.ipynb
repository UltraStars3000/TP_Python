# %% [markdown]
# **Mélanger un taquin**

# %%
from tkinter import *
from random import *

CANVAS_SIDE=400
NB_SQUARES=4
R=CANVAS_SIDE//NB_SQUARES

master=Tk()
cnv=Canvas(master, width=CANVAS_SIDE, height=CANVAS_SIDE, bg='ivory')
cnv.pack()

def fill_board(cnv, board):
    for i in range(NB_SQUARES):
        for j in range(NB_SQUARES):
            v=board[i][j]
            if not i==j==NB_SQUARES-1:
                cnv.create_rectangle(j*R, i*R, (1+j)*R, (1+i)*R, fill="lavender")
                cnv.create_text(j*R+R//2, i*R+R//2, text=v,  font=('courier', CANVAS_SIDE//10, 'bold'))

def draw():
    cnv.pack()

    board=[[NB_SQUARES*lin+1+col for col in range(NB_SQUARES)] for lin in range(NB_SQUARES)]
    fill_board(cnv, board)

def melange():
    fdp=[]
    for x in range(1, NB_SQUARES*NB_SQUARES):
        fdp.append(x)
    shuffle(fdp)
    x=0
    for i in range(NB_SQUARES):
        for j in range(NB_SQUARES):
            v=fdp[x-1]
            x=x+1
            if not i==j==NB_SQUARES-1:
                cnv.create_rectangle(j*R, i*R, (1+j)*R, (1+i)*R, fill="lavender")
                cnv.create_text(j*R+R//2, i*R+R//2, text=v,  font=('courier', CANVAS_SIDE//10, 'bold'))
    
draw()

btn = Button(master, text="Mélanger", command=melange)
btn.pack()

master.mainloop()

# %% [markdown]
# **Automate de feu de forêt**

# %%
from random import sample
from tkinter import Tk, Canvas

def random_forest(p, n):
    units=[(line,col) for col in range(n) for line in range(n)]
    ntrees=int(n**2*p)
    trees=sample(units,ntrees)
    print(trees)
    states=[[0]*n for _ in range(n)]
    for (i,j) in trees:
        if (i,j)==trees[0]:
            states[i][j]=2
        else:
            states[i][j]=1
    return states
                
def fill(cnv, states, unit):
    n=len(states)
    for line in range(n):
        for col in range(n):
            A=(unit*col, unit*line)
            B=(unit*(col+1), unit*(line+1))
            state=states[line][col]
            color=["ivory", "lime green", "red", "gray75"][state]
            cnv.create_rectangle(A, B, fill=color, outline='')


p=0.2
n=50

root = Tk()
unit=10 #Global size
side=unit*n #Canvas size
cnv = Canvas(root, width=unit*n, height=unit*n, background="ivory")
cnv.pack(padx=10, pady=10)
states=random_forest(p,n) #Liste ?
fill(cnv, states, unit)
root.mainloop()
# Out:
# [(33, 23), (15, 10), (14, 9), (14, 40), (8, 19), (24, 31), (29, 17), (47, 30), (41, 8), (10, 46), (16, 46), (4, 4), (22, 38), (30, 47), (22, 15), (9, 42), (10, 33), (39, 41), (26, 44), (44, 38), (0, 3), (45, 32), (8, 36), (41, 2), (24, 41), (38, 10), (18, 30), (0, 31), (29, 12), (24, 4), (0, 36), (41, 41), (36, 8), (26, 12), (23, 41), (40, 21), (43, 49), (21, 37), (0, 37), (45, 22), (27, 6), (20, 0), (31, 36), (41, 34), (23, 38), (25, 37), (13, 27), (23, 9), (1, 40), (43, 34), (10, 23), (1, 15), (16, 17), (49, 16), (47, 28), (10, 7), (41, 37), (1, 29), (44, 7), (14, 4), (18, 34), (13, 10), (13, 44), (29, 47), (3, 30), (27, 29), (12, 21), (5, 6), (21, 31), (42, 44), (35, 20), (39, 7), (23, 25), (2, 37), (26, 13), (33, 7), (1, 5), (31, 49), (7, 4), (0, 40), (41, 32), (29, 20), (24, 36), (6, 45), (35, 9), (45, 0), (10, 45), (40, 46), (38, 15), (46, 37), (42, 7), (44, 28), (21, 2), (19, 14), (15, 28), (17, 27), (42, 20), (4, 7), (12, 27), (32, 17), (12, 13), (41, 30), (26, 35), (49, 25), (49, 28), (2, 18), (23, 26), (32, 6), (38, 18), (21, 34), (2, 10), (41, 12), (18, 33